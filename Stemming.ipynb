# %% [markdown]
# Stemming

# %%
# import the toolkit and the full porter stemmer library
import nltk

from nltk.stem.porter import PorterStemmer

# %%
p_stemmer = PorterStemmer()

# %%
words = ['run', 'runne','runner','running','easily','fairly','fairness']

# %%
for words in words:
  print(words + '---->' + p_stemmer.stem(words))
# Out:
# run---->run
# runne---->runn
# runner---->runner
# running---->run
# easily---->easili
# fairly---->fairli
# fairness---->fair

# %% [markdown]
# snowball stemmer

# %%
from nltk.stem.snowball import SnowballStemmer

# the snowball stemmer requires that you  pass a language parameter
s_stemmer = SnowballStemmer(language='english')

# %%
words = ['run', 'runne','runner','running','easily','fairly','fairness']
# words = ['geneous','generation','geneously','geneate']

# %%
for word in words:
  print(word + '---->' + s_stemmer.stem(word))
# Out:
# run---->run
# runne---->runn
# runner---->runner
# running---->run
# easily---->easili
# fairly---->fair
# fairness---->fair

# %%
words = ['consolingly']

# %%
print('Porter Stemmer:')
for word in words:
  print(word + '---->' + p_stemmer.stem(word))
# Out:
# Porter Stemmer:
# consolingly---->consolingli

# %%
print('snowball Stemmer:')
for word in words:
  print(word + '---->' + s_stemmer.stem(word))
# Out:
# snowball Stemmer:
# consolingly---->consol

# %%
phrase = 'I am meeting him tomorrow at the meeting'
for word in phrase.split():
  print(word + '---->' + p_stemmer.stem(word))
# Out:
# I---->i
# am---->am
# meeting---->meet
# him---->him
# tomorrow---->tomorrow
# at---->at
# the---->the
# meeting---->meet

# %%
phrase = 'I am meeting him tomorrow at the meeting'
for word in phrase.split():
  print(word + '---->' + s_stemmer.stem(word))
# Out:
# I---->i
# am---->am
# meeting---->meet
# him---->him
# tomorrow---->tomorrow
# at---->at
# the---->the
# meeting---->meet
