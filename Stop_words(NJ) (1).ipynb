# %%
import spacy
nlp = spacy.load("en_core_web_sm")

# %%
print(nlp.Defaults.stop_words)
# Out:
# {'without', 'have', 'used', 'made', 'back', 'the', 'through', 'themselves', 'herein', 'thence', 'whole', 'everywhere', 'amongst', 'my', 'yourselves', 'forty', 'even', 'name', 'take', 'whence', 'beforehand', 'must', 'never', 'via', 'side', 'anywhere', 'always', 'except', 'nobody', 'still', 'those', 'five', 'everything', 'n‘t', 'sometimes', 'none', 'became', 'whoever', 'not', "'d", 'out', 'eleven', 'same', 'whether', 'them', 'ca', 'thereafter', 'up', 'both', 'elsewhere', 'rather', 'whatever', 'when', 'towards', 'hereby', 'do', 'nothing', 'on', 'thereupon', 'being', 'ten', 'perhaps', 'first', 'has', 'doing', "'ve", 'might', 'since', 'neither', 'fifteen', 'third', 'any', 'empty', 'next', 'only', 'her', 'yourself', 'latter', 'from', '‘m', '‘re', 'below', 'n’t', 'over', 'that', 'others', 'were', 'however', 'before', 'done', 'each', 'several', 'three', 'see', 'using', 'now', 'hence', 'are', 'front', 'which', 'should', 'just', 'under', 'formerly', 'say', 'across', 'no', 'part', 'i', 'becoming', 'top', 'then', 'ever', '‘ve', 'whereas', 'someone', 'between', 'at', 'four', 'ours', 'noone', 'it', 'she', 'your', 'and', 'is', 'moreover', 'could', 'become', 'although', 'upon', 'therefore', 'may', 'else', 'seeming', "n't", 'seem', 'six', 'for', 'an', 'beside', 'along', 'anyone', 'most', 'behind', 'why', 'every', '’s', 'mostly', 'give', 'full', 'go', 'really', 'seemed', 'herself', '’m', 'last', 'had', 'be', 'while', 'of', 'wherever', 'eight', 'a', 'somehow', 'all', 'besides', 'beyond', 'unless', 'there', 'cannot', 'can', 'does', 'therein', 'was', 'himself', 'our', 'two', 'fifty', 'twenty', 'thereby', 'already', '‘s', 'please', 'something', 'by', 'throughout', 'amount', 'various', 'we', 'so', 'this', "'m", 'because', 'yours', 'to', 'together', 'nine', 'did', 'whose', 'everyone', 'what', 'another', 'anyway', 'move', 'against', 'they', 'into', 'him', 'will', 'make', 'you', 'or', 'too', 'itself', 'sixty', 'own', 'indeed', 'regarding', 'after', 'sometime', 'hundred', 'get', 'former', 'afterwards', 'often', 'thus', 'would', 'whither', 'somewhere', 'in', 'per', 'he', 're', 'am', 'within', 'very', 'me', 'show', 'whereupon', 'twelve', 'how', 'thru', 'above', 'more', 'least', 'whereby', "'s", 'been', 'around', 'keep', 'hereupon', 'if', 'latterly', 'his', 'further', 'though', 'due', 'wherein', 'myself', 'down', 'once', 'few', 'off', 'hers', 'well', 'again', "'ll", 'enough', 'such', 'whenever', 'who', 'among', 'nowhere', 'quite', 'many', 'than', 'but', 'whereafter', 'call', 'serious', 'with', 'namely', 'us', 'also', 'here', 'as', 'these', 'either', 'onto', 'much', 'some', 'otherwise', 'during', 'their', 'until', 'nevertheless', 'anyhow', "'re", 'less', 'meanwhile', 'one', 'becomes', 'yet', 'ourselves', 'mine', 'seems', 'anything', 'alone', '’re', 'about', 'whom', 'almost', '’ll', 'other', 'where', '‘d', 'bottom', 'nor', 'hereafter', '’d', '’ve', 'its', 'put', '‘ll', 'toward'}

# %%
len(nlp.Defaults.stop_words)
# Out:
# 326

# %% [markdown]
# TO see if a word is stop word or not

# %%
nlp.vocab['myself'].is_stop
# Out:
# True

# %%
nlp.vocab['mystery'].is_stop
# Out:
# False

# %% [markdown]
# To add a stop word

# %%
nlp.Defaults.stop_words.add('btw')

# %%
nlp.vocab['btw'].is_stop
# Out:
# True

# %%
len(nlp.Defaults.stop_words)
# Out:
# 327

# %% [markdown]
# To remove a stop word

# %%
nlp.vocab['beyond'].is_stop
# Out:
# True

# %%
# remove the word from stop word
nlp.Defaults.stop_words.remove('beyond')

# remove the stop_words tag from the lexeme
nlp.vocab['beyond'].is_stop = False

# %%
len(nlp.Defaults.stop_words)
# Out:
# 326

# %%
nlp.vocab['beyond'].is_stop
# Out:
# False
