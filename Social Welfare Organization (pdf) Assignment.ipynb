# %%
pip install PyPDF2
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import PyPDF2

# %%
f=open("Social Welfare Organizations.pdf","rb")

# %%
f
# Out:
# <_io.BufferedReader name='Social Welfare Organizations.pdf'>

# %%
pdf_reader = PyPDF2.PdfReader(f)

# %%
pdf_reader

# %%
len(pdf_reader .pages)
# Out:
# 16

# %%
page_one = pdf_reader.pages[0]

# %%
page_one
# Out:
# {'/Contents': [IndirectObject(100, 0, 2777827286944),
#   IndirectObject(101, 0, 2777827286944),
#   IndirectObject(102, 0, 2777827286944),
#   IndirectObject(103, 0, 2777827286944),
#   IndirectObject(104, 0, 2777827286944),
#   IndirectObject(105, 0, 2777827286944),
#   IndirectObject(106, 0, 2777827286944),
#   IndirectObject(108, 0, 2777827286944)],
#  '/CropBox': [0, 0, 595.32, 841.92],
#  '/Group': {'/CS': '/DeviceRGB',
#   '/I': False,
#   '/K': False,
#   '/S': '/Transparency',
#   '/Type': '/Group'},
#  '/MediaBox': [0, 0, 595.32, 841.92],
#  '/Parent': {'/Count': 6,
#   '/Kids': [IndirectObject(96, 0, 2777827286944),
#    IndirectObject(1, 0, 2777827286944),
#    IndirectObject(5, 0, 2777827286944),
#    IndirectObject(9, 0, 2777827286944),
#    IndirectObject(16, 0, 2777827286944),
#    IndirectObject(20, 0, 2777827286944)],
#   '/Parent': {'/Count': 16,
#    '/Kids': [IndirectObject(90, 0, 2777827286944),
#     IndirectObject(91, 0, 2777827286944),
# ...

# %%
page_one_text = page_one.extract_text()

# %%
page_one_text
# Out:
# 'Functions, Principles and\nScope of Social Welfare UNIT 3 SOCIAL WELFARE\nORGANIZATIONS\nContents\n3.0     Objectives\n3.1     Introduction\n3.2 Types of Social Welfare Organizations\n3.3 Governmental Organizations\n3.4 Non- Government Organizations\n3.5 Bilateral and International Organizations\n3.6 Donor Agencies and United Nations Bodies3.7 Let Us Sum Up\n3.8 Key Words\n3.9 Further Readings and References\n3.0 OBJECTIVES\nThis unit will give you an understanding of the different social welfare\norganizations that are working in the social welfare sector. These include theGovernmental, Non-governmental, Bilateral and International organization. Theunit will also explain the governance of the social welfare organization, the\nmanner in which they function and their main areas of intervention.\n3.1 INTRODUCTION\nA ‘Service’ is termed a ‘Social’ if its aims the enhancement of the welfare of\nthe individual or the community either through personal effort or by collectiveaction.  Socia
# ...

# %%
f=open("Social Welfare Organizations.pdf","rb")

# %%
pdf_reader = PyPDF2.PdfReader(f)

# %%
first_page = page = pdf_reader.pages[0]

# %%
pdf_writer = PyPDF2.PdfWriter(f)

# %%
pdf_writer.add_page(first_page)
# Out:
# {'/Contents': [IndirectObject(5, 0, 2777827361616),
#   IndirectObject(6, 0, 2777827361616),
#   IndirectObject(7, 0, 2777827361616),
#   IndirectObject(8, 0, 2777827361616),
#   IndirectObject(9, 0, 2777827361616),
#   IndirectObject(10, 0, 2777827361616),
#   IndirectObject(11, 0, 2777827361616),
#   IndirectObject(12, 0, 2777827361616)],
#  '/CropBox': [0, 0, 595.32, 841.92],
#  '/Group': {'/CS': '/DeviceRGB',
#   '/I': False,
#   '/K': False,
#   '/S': '/Transparency',
#   '/Type': '/Group'},
#  '/MediaBox': [0, 0, 595.32, 841.92],
#  '/Resources': {'/ColorSpace': {'/CS0': ['/Indexed',
#     IndirectObject(15, 0, 2777827361616),
#     0,
#     IndirectObject(17, 0, 2777827361616)],
#    '/CS1': ['/ICCBased', IndirectObject(16, 0, 2777827361616)]},
#   '/ExtGState': {'/GS0': {'/CA': 0.100006,
#     '/Type': '/ExtGState',
#     '/ca': 0.100006},
#    '/GS1': {'/AIS': False,
#     '/BM': '/Normal',
#     '/CA': 1,
#     '/OP': False,
#     '/OPM': 1,
#     '/SA': True,
# ...

# %%
pdf_output = open("new_doc.pdf","wb")

# %%
pdf_writer.write(pdf_output)
# Out:
# (False, <_io.BufferedWriter name='new_doc.pdf'>)

# %%
pdf_output.close()

# %%
f.close()

# %%
f = open("new_doc.pdf","rb")

# %%
pdf_reader = PyPDF2.PdfReader(f)

# %%
len(pdf_reader.pages)
# Out:
# 1

# %%
page_one = pdf_reader .pages[0]

# %%
page_one_text = page_one.extract_text()

# %%
page_one_text
# Out:
# 'Functions, Principles and\nScope of Social Welfare UNIT 3 SOCIAL WELFARE\nORGANIZATIONS\nContents\n3.0     Objectives\n3.1     Introduction\n3.2 Types of Social Welfare Organizations\n3.3 Governmental Organizations\n3.4 Non- Government Organizations\n3.5 Bilateral and International Organizations\n3.6 Donor Agencies and United Nations Bodies3.7 Let Us Sum Up\n3.8 Key Words\n3.9 Further Readings and References\n3.0 OBJECTIVES\nThis unit will give you an understanding of the different social welfare\norganizations that are working in the social welfare sector. These include theGovernmental, Non-governmental, Bilateral and International organization. Theunit will also explain the governance of the social welfare organization, the\nmanner in which they function and their main areas of intervention.\n3.1 INTRODUCTION\nA ‘Service’ is termed a ‘Social’ if its aims the enhancement of the welfare of\nthe individual or the community either through personal effort or by collectiveaction.  Socia
# ...

# %%
f=open("Social Welfare Organizations.pdf","rb")

# %%
pdf_text=[]

# %%
for p in range(len(pdf_reader.pages)):
    page = pdf_reader.pages[p]

# %%
pdf_text.append(page.extract_text())

# %%
for page in pdf_text:
    print(page)
# Out:
# <bound method PageObject.extract_text of {'/Contents': [IndirectObject(5, 0, 2777828314048), IndirectObject(6, 0, 2777828314048), IndirectObject(7, 0, 2777828314048), IndirectObject(8, 0, 2777828314048), IndirectObject(9, 0, 2777828314048), IndirectObject(10, 0, 2777828314048), IndirectObject(11, 0, 2777828314048), IndirectObject(12, 0, 2777828314048)], '/CropBox': [0, 0, 595.32, 841.92], '/Group': IndirectObject(13, 0, 2777828314048), '/MediaBox': [0, 0, 595.32, 841.92], '/Resources': {'/ColorSpace': {'/CS0': IndirectObject(14, 0, 2777828314048), '/CS1': IndirectObject(15, 0, 2777828314048)}, '/ExtGState': {'/GS0': IndirectObject(18, 0, 2777828314048), '/GS1': IndirectObject(19, 0, 2777828314048)}, '/Font': {'/TT0': IndirectObject(20, 0, 2777828314048), '/TT1': IndirectObject(24, 0, 2777828314048), '/TT2': IndirectObject(28, 0, 2777828314048)}, '/ProcSet': ['/PDF', '/Text', '/ImageC', '/ImageI'], '/XObject': {'/Fm0': IndirectObject(32, 0, 2777828314048), '/Im0': IndirectObject(39, 0
# ...
